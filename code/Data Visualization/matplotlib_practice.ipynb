# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,31,12)
y = (x**2)

# %%
x
# Out:
# array([ 0.        ,  2.81818182,  5.63636364,  8.45454545, 11.27272727,
#        14.09090909, 16.90909091, 19.72727273, 22.54545455, 25.36363636,
#        28.18181818, 31.        ])

# %%
y
# Out:
# array([  0.        ,   7.94214876,  31.76859504,  71.47933884,
#        127.07438017, 198.55371901, 285.91735537, 389.16528926,
#        508.29752066, 643.31404959, 794.21487603, 961.        ])

# %% [markdown]
# ## Functional Method for Plotting

# %%
plt.plot(x, y, 'b-')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y, 'r')

plt.subplot(1, 2, 2)
plt.plot(y, x, 'b')

# %% [markdown]
# ## OOP Method for Plots

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.9])
axes.plot(x,y)
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# ### first method (more manual)

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.4, 0.3, 0.4])

axes1.plot(x, y)
axes1.set_title('large')
axes2.plot(y, x)
axes2.set_title('small')
# Out:
# Text(0.5, 1.0, 'small')

# %% [markdown]
# ### second method (subplots arranged by rows and columns)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
plt.tight_layout()

# iter over axes object
# for current_ax in axes:
#     current_ax.plot(y,x)

# can index axes object too
axes[0].plot(x, y)
axes[0].set_title('first plot xy')

axes[1].plot(y, x)
axes[1].set_title('second plot yx')

plt.tight_layout()

# %%
# axes object is an array of matplotlib axes (list of axes objects) can iter over it
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %% [markdown]
# ## Figure Size and DPI

# %%
# fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(4,2), dpi=200)

# ax = fig.add_axes([0,0,1,1])
# ax.plot(x, y)

# axes[0].plot(x, y)
# axes[0].set_title('X v. Y')
# axes[0].set_ylabel('Y')
# axes[0].set_xlabel('X')

# axes[1].plot(y, x)
# axes[1].set_title('Y v. X')
# axes[1].set_ylabel('X')
# axes[1].set_xlabel('Y')

fig = plt.figure(dpi=300)

ax = fig.add_axes([0,0,1,1])
ax.plot(x, y*2, label='Y square')
ax.plot(x, y*3, label='Y cube')

ax.legend(loc=(0.1, 0.2))

# plt.tight_layout()

# %% [markdown]
# ### save a figure to a file (png, tiff, jpg, etc.)

# %%
fig.savefig('figure1.png', dpi=320)

# %% [markdown]
# ## Plot Appearance

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x, y, color='blue', 
        lw=1, 
        ls='-', 
        marker='o', 
        ms=10,
       markerfacecolor='yellow',
        markeredgecolor='black',
        markeredgewidth=2
       ) # RGB Hex Code

# %% [markdown]
# ### control over axis appearnace and plot range

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x, y, color='purple', lw=1, ls='--')

# only show the plot between 0 and 1 on the x-axis
ax.set_xlim([0,5])
ax.set_ylim([0, 15])
# Out:
# (0.0, 15.0)

# %% [markdown]
# ## Special plot types
